# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
# !pip install transformers==2.1.0
# !pip install gensim==4.1.2
# !pip3 install --user underthesea
# !pip install tensorflow_addons
# !pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim==4.1.2 in /usr/local/lib/python3.7/dist-packages (4.1.2)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (5.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim==4.1.2) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: underthesea in /root/.local/lib/python3.7/site-packages (1.3.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from underthesea) (1.0.2)
# Requirement already satisfied: python-crfsuite>=0.9.6 in /root/.local/lib/python3.7/site-packages (from underthesea) (0.9.8)
# Requirement already satisfied: unidecode in /root/.local/lib/python3.7/site-packages (from underthesea) (1.3.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from underthesea) (2.23.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from underthesea) (7.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from underthesea) (6.0)
# Requirement already satisfied: underthesea-core==0.0.4_alpha.10 in /root/.local/lib/python3.7/site-packages (from underthesea) (0.0.4a10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from underthesea) (4.64.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from underthesea) (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from underthesea) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk->underthesea) (2022.6.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->underthesea) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->underthesea) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.7/dist-packages (0.18.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)

# %%
#from pyvi import ViTokenizer, ViPosTagger
import regex as re
from underthesea import word_tokenize
import numpy as np
import pandas as pd
import gensim
import sklearn
import tensorflow as tf
from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import classification_report
from tensorflow.keras.layers import *
from keras.layers import *
from keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.metrics import sparse_categorical_accuracy
from tensorflow.keras.optimizers import Adam
# Chia tập train/test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
dicchar = loaddicchar()

# Hàm chuyển Unicode dựng sẵn về Unicde tổ hợp (phổ biến hơn)
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

def chuan_hoa_dau_cau_tieng_viet(sentence):
    """
        Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
        :param sentence:
        :return:
        """
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        words[index] = ''.join(cw)
    return ' '.join(words)

def remove_html(txt):
    return re.sub(r'<[^>]*>', '', txt)

# %%
def text_preprocess(document):
    # xóa html code
    document = remove_html(document)
    # chuẩn hóa unicode
    document = convert_unicode(document)
    
    # đưa về lower
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # tách từ
    document = word_tokenize(document, format="text")
    return document

# %%
# lst_stopword = []
# with open('/content/drive/MyDrive/KhanhMD/Data/vietnamese-stopwords.txt','r') as f:
#     for line in f:
#         for word in line.split():
#            lst_stopword.append(word)  
    
# def remove_stopwords(line):
#     words = []
#     for word in line.strip().split():
#         if word not in lst_stopword:
#             words.append(word)
#     return ' '.join(words)

# %%
with open('/content/drive/MyDrive/KhanhMD/Data/data_pos.txt', 'r') as file:
    data_pos = file.read().replace('\n', '/27121998/')

# %%
with open('/content/drive/MyDrive/KhanhMD/Data/data_neg.txt', 'r') as file:
    data_neg = file.read().replace('\n', '/27121998/')

# %%
clean_data_pos = text_preprocess(data_pos)

đó cũng ko có hàng cháo bồ_câu hình chụp nguyên con bồ_câu mà tìm hoài chỉ thấy phao_câu không thấy đầu bồ_câu hỏi e nv e chạy hỏi nhà_bếp đc trả_lời là 1 phần cháo đc tính_toán 1_lượng thịt cố_định theo gram chứ không phải nguyên con chị ơi ps lần sau sẽ rủ trên 4 đứa đi quẩy để đc tặng 10 ly biaaaaaaaaaaaaaa mí đc',
#  'mình đi với nhóm tổng_cộng 4 người ăn chỉ có không tới 150 k mà no luôn í một con cá_lóc nướng to thiệt to kèm với rau_sống bún bánh_tráng đồ luôn là có 90 k ah bắp giò 69 k để gói cuốn bánh_tráng chung bún thêm 5 k bánh_tráng thêm 8 k nữa đồ_ăn rẻ thích_hợp ăn_uống cuối tuần cho gia_đình tuy_nhiên mình thấy nước_chấm không ngon mắm_nêm có mùi gừng ăn kỳ_kỳ cá thì nguội quá chắc là nướng lâu rồi không hâm_nóng lại',
#  'nhân_viên phục_vụ không mấy tận_tình đồ_ăn ra lâu và không đều món cơm thịt bò nướng ngon còn mì soba xào không được ngon cho lắm',
#  'vào đây thì hết bàn nhưng mình vẫn ngồi đợi bình_thường để nhân_viên dọn_bàn ai_ngờ dọn xong họ cho tốp khách sau vào ngồi còn mình thì như vô_hình bị lơ mình cười nửa miệng rồi bước ra khỏi quán có_lẽ vì mình đi 1 mình nên họ ưu_tiên nhóm đông người vì lợi_nhuận mà xem_thường khách phục_vụ và phong_cách làm_việc quá tệ_hại chưa ăn nhưng dù có ngon thì với cách đón_tiếp kiểu này thì mình cũng cho vào sổ_đen',
#  'hôm_nay đến aeon có ghé vào quán món ăn cũng khá nhưng hơi ít không_gian quán cũng ổn',
#  'mình vào lúc 8 h tối cũng không đông khách lắm nhưng chờ hơi lâu order 4 món thì ăn giống như nhét kẽ răng ko_xi nhê phải thêm cái lẩu cá sả nữa mới tạm no giá hơi mắc đồ_ăn thì hơi ít hình_ảnh trên menu đúng mang tính_chất minh_hoạ như em phục_vụ_bàn nói có món gà trứng gì đó trong menu để must try mà mình kiu lên thử thấy thất_vọng vô_cùng 5 người 5 cục_thịt gà với mấy cục tỏi không thấy cái trứng nào hết dĩa gỏi bò có vài lát bò còn lại rau với rau nói_chung tới ăn 1 lần cho_biết chứ không có ý_định quay lại',
#  'thức_ăn quá_đỗi bình_thường miếng xôi của bạn mình ăn còn sạn mắc ko xứng_đáng vs giá_cả',
#  'lần đầu_tiên ăn_chắc cũng là lần cuối ăn_ở đây quá món ăn thì không có gì đặc_sắc giá_cả thì mắc đồ_ăn thì không được nhìu nói_chung là mình thấy bình_thường so với một nhà_hàng tầm_cỡ như_vậy thất_vọng']

# %%
import pandas as pd
df = pd.DataFrame(text_pos, columns=["text"])
df.to_csv('text_pos.csv', index=False)

# %%
text_pos_pd = pd.read_csv('text_pos.csv')
text_pos_pd[:10]
# Out:
#                                                 text
# 0  đây là nhà_thờ được cho là lớn nhất huế lại nằ...
# 1  cơm hến bún hến ở chợ phú lộc nghe lâu rồi mà ...
# 2  resort ngay trung_tâm cách phố cổ tầm 700 m 1 ...
# 3  chỉ cách phổ cổ khoảng 1 km nên khách_sạn này ...
# 4  hôm_nay mình quay lại quán cùng_với mấy người ...
# 5  bánh và nước rất rất ngon phục_vụ nhiệt_tình c...
# 6  hôm đấy ngẫu_hứng tới nồi vì đang có chương_tr...
# 7  nghe tên quán_từ rất lâu rồi đọc review cũng t...
# 8  mình đến nồi_bay hôm trước và có gọi bánh mous...
# 9  tổng_hợp từ 2 lần em đến với nồi_bay bình_thườ...

# %%
text_pos_pd=text_pos_pd.assign(label=lambda x: 1)

# %%
df_0 = pd.DataFrame(text_neg, columns=["text"])
df_0.to_csv('text_neg.csv', index=False)

# %%
text_neg_pd = pd.read_csv('text_neg.csv')
text_neg_pd[:10]
# Out:
#                                                 text
# 0  mua có mỗi bingsu thập_cẩm 45 k mà mình f đợi ...
# 1  quán này khá là nổi_tiếng nay mới có dịp ghé t...
# 2  thứ 6 nào ta cùng quẩy vuvuzela beer club chun...
# 3  mình đi với nhóm tổng_cộng 4 người ăn chỉ có k...
# 4  nhân_viên phục_vụ không mấy tận_tình đồ_ăn ra ...
# 5  vào đây thì hết bàn nhưng mình vẫn ngồi đợi bì...
# 6  hôm_nay đến aeon có ghé vào quán món ăn cũng k...
# 7  mình vào lúc 8 h tối cũng không đông khách lắm...
# 8  thức_ăn quá_đỗi bình_thường miếng xôi của bạn ...
# 9  lần đầu_tiên ăn_chắc cũng là lần cuối ăn_ở đây...

# %%
text_neg_pd=text_neg_pd.assign(label=lambda x: 0)

# %%
df_concat_col = pd.concat([text_pos_pd, text_neg_pd])
df_concat_col.to_csv("data.csv", index=False)

# %%
c = pd.read_csv("data.csv")
c[:10]
# Out:
#                                                 text  label
# 0  đây là nhà_thờ được cho là lớn nhất huế lại nằ...      1
# 1  cơm hến bún hến ở chợ phú lộc nghe lâu rồi mà ...      1
# 2  resort ngay trung_tâm cách phố cổ tầm 700 m 1 ...      1
# 3  chỉ cách phổ cổ khoảng 1 km nên khách_sạn này ...      1
# 4  hôm_nay mình quay lại quán cùng_với mấy người ...      1
# 5  bánh và nước rất rất ngon phục_vụ nhiệt_tình c...      1
# 6  hôm đấy ngẫu_hứng tới nồi vì đang có chương_tr...      1
# 7  nghe tên quán_từ rất lâu rồi đọc review cũng t...      1
# 8  mình đến nồi_bay hôm trước và có gọi bánh mous...      1
# 9  tổng_hợp từ 2 lần em đến với nồi_bay bình_thườ...      1

# %%
c = c.sample(frac=1).reset_index(drop=True)

# %%
df = c.copy()
df[:50]
# Out:
#                                                  text  label
# 0   mình hay đến đây mua bánh pararoti và su kem b...      1
# 1   thật kinh_khủng chưa bao_giờ thấy cái kiểu phụ...      0
# 2   nhân_viên nhiệt_tình thân_thiện và vui_tính ch...      1
# 3   đà_nẵng được mệnh_danh là thành_phố của những ...      1
# 4   mình đi vào cuối tuần quán đông nhưng nhân_viê...      0
# 5   trà sữa ngon bánh ngon mỗi_tội lớp vỏ bánh_hơi...      1
# 6   thấy nhiều người review ok với_lại mỗi lần chạ...      0
# 7   cảm_giác lần đầu_tiên đến quán_hs hoàng_thành ...      1
# 8   haizz đã tới đây một lần và không_bao_giờ muốn...      0
# 9   mình đến lần đầu_tiên vào buổi tối nên thấy qu...      0
# 10  mình đã ở đây từ hồi còn nhỏ nên mình hiểu rõ ...      0
# 11  từ ngoài bãi gửi xe thì xe để lộn_xộn o có ngư...      0
# 12  cực đẹp và cực thoáng mát khi nói về không_gia...      1
# 13  mình rất ư là thích cappuccino ở passio ở đây ...      0
# 14  táng tộn ngon và đầy hộp mỗi_tội ăn hết hộp th...      0
# 15  đồ_ăn không ngon lắm 354 k cho 2 đừa quá mắc s...      0
# 16  hôm trước vừa ghé qua ăn thử gà mẹt ở đây gà ở...      0
# 17  quán ở đây nhỏ xinh nằm kế bên tour les jour đ...      1
# 18  đợt đi huế vừa_rồi mình có ghé quán_ăn vì có n...      0
# 19  chuyện là bọn mình đi 5 người nhưng có đứa đã ...      0
# 20  lạnh rồi nên đi ăn đồ hàn quốc là quá chuẩn qu...      1
# 21  em go ̣ i ba ̀ i ha ̃ i chi_̣ phu ̣ c vu ̣ ma_...      0
# 22       thích nhất món heo nướng còn lại thì cũng ổn      0
# 23  từ ngày lên foody thì quán này đông hơn tất_nh...      0
# 24  dở_tệ gọi tô lớn ghẹ bóc sẵn mà số_lượng thịt ...      0
# 25  cảnh đẹp thích_hợp để chụp hình lâu_lâu lại có...      1
# 26  this restaurant is terrible their mi quang tas...      0
# 27  chỉ có lẩu dê lẩu bò giá cũng ko rẻ lắm nồi lẩ...      0
# 28  mình đi cùng chồng ghé qua đây ngồi với bạn_bè...      0
# 29  quán to đẹp dễ tìm anh chủ quán thân_thiện quá...      1
# 30  nhìn thấy trang_trí đẹp nhưng bánh không ngon ...      0
# 31  mọi góc của rdc đều đc trang_trí rất đẹp bước ...      1
# 32  hôm_nay mình dắt 3 đứa bạn mình đi ăn_ở sumo_c...      0
# 33  dừng chân ở huế vào 1 buổi chiều chúng_tôi tìm...      1
# 34  nằm ngay gần đại_học ngoại_thương với học_viện...      0
# 35  quán này bánh ngon_ăn cái là ấm_bụng rồi 2 cái...      0
# 36  quán ốc làm ngon giá rẻ ốc tươi nhưng quá đông...      0
# 37  lúc đầu mình đến ăn có món bánh_tráng trứng và...      1
# 38  điểm đến lý tưỡng khi đến thành_phố biển quy_n...      1
# 39  mình thích vị cacao bạc_hà dễ_ăn và thơm match...      1
# 40  mình đi quán 3 cây chổi 2 lần_lần nào cũng nhậ...      0
# 41  quán_ăn bày trí khá bắt_mắt không_gian thoáng ...      1
# 42  th mart này gần nhà nhưng hôm_nay mới ghé thử ...      1
# 43  quán bán tàu_hủ tuy nhỏ nhưng sạch_sẽ và gọn_g...      1
# 44  không_gian ngộp nóng_nực mình tới vào giờ trưa...      0
# 45  đi giữa trưa ngồi ở dưới nên hơi nóng trang_tr...      1
# 46  quán bài_trí dễ_thương và crepe cũng rất ngon ...      0
# 47  đi qua quán này nhiều lần nhưng k vào vì quán ...      0
# 48  nghe danh quán nhiều và được nhiều người khen ...      0
# 49  không_gian quán mộc_mạc ấm_cúng udon ở đây khá...      1

# %%
df.shape
# Out:
# (24734, 2)

# %%
text = clean_data_pos +' '+ clean_data_neg

# %%
text = text.split(' 27121998 ')

# %%
split_text = [s.split() for s in text]

# %%
len(split_text)
# Out:
# 24734

# %%
w2v = gensim.models.Word2Vec(split_text,
                                   vector_size=100,
                                   window=5,
                                   min_count=1)
words = set(w2v.wv.index_to_key)

# %%
w2v.train(split_text ,epochs=10,total_examples=len(split_text ))
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (17853834, 21409250)

# %%
vocab=w2v.wv.key_to_index
print("The total number of words are : ",len(vocab))
# Out:
# The total number of words are :  35482

# %%
vocab=list(vocab.keys())

# %%
word_vec_dict={}
for word in vocab:
  word_vec_dict[word]=w2v.wv.get_vector(word)
print(len(word_vec_dict))
# Out:
# 35482

# %%
# maxi=-1
# for i,rev in enumerate(df['text']):
#     tokens=rev.split()
#     if(len(tokens)>maxi):
#         maxi=len(tokens)
# print(maxi)

# %%
tok = Tokenizer()
tok.fit_on_texts(df['text'])
vocab_size = len(tok.word_index) + 1
encd_rev = tok.texts_to_sequences(df['text'])

# %%
max_rev_len=125  # max lenght of a review
vocab_size = len(tok.word_index) + 1  # total no of words
embed_dim=100

# %%
from keras.preprocessing.sequence import pad_sequences
pad_rev= pad_sequences(encd_rev, maxlen=max_rev_len, padding='post')
pad_rev.shape
# Out:
# (24734, 125)

# %%
pad_rev
# Out:
# array([[ 164,   33,   48, ...,  117, 1129,   95],
#        [ 303, 1179,   91, ...,  131,   22,  182],
#        [  27,   26,  151, ...,    0,    0,    0],
#        ...,
#        [1635,   41,   77, ..., 5481,    0,    0],
#        [  70,  131,   22, ...,    0,    0,    0],
#        [ 104,  112,   21, ...,    0,    0,    0]], dtype=int32)

# %%
embed_matrix=np.zeros(shape=(vocab_size,embed_dim))
for word,i in tok.word_index.items():
  embed_vector=word_vec_dict.get(word)
  if embed_vector is not None:  # word is in the vocabulary learned by the w2v model
    embed_matrix[i]=embed_vector

# %%
embed_matrix.shape
# Out:
# (18184, 100)

# %%
import keras
import keras.utils
from keras import utils as np_utils
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.utils import np_utils
sklearn.model_selection.train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
# !pip install np_utils
from keras.utils.np_utils import to_categorical

# %%
# Y=keras.utils.to_categorical(df['label'])
# Y.shape
from keras import utils as np_utils
Y=keras.utils.np_utils.to_categorical(df['label'])  # one hot target as required by NN.

# %%
y = np.array(df['label'])
y = y.reshape(y.size,1)
y
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
X_train, X_test, y_train, y_test = train_test_split(pad_rev, y, test_size=0.2, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42) # 0.9 x 0.8 = 0.2

# %%
from keras.initializers import Constant
from keras.layers import ReLU
from keras.layers import Dropout
model=Sequential()
model.add(Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_rev_len,embeddings_initializer=Constant(embed_matrix)))
model.add(Bidirectional(LSTM(128)))
model.add(Flatten())
model.add(Dense(64,activation='relu',kernel_regularizer='l2'))
model.add(Dropout(0.2))

#model.add(Dense(1024,activation='relu'))
# model.add(Dense(64,activation='relu',kernel_regularizer='l2'))
# model.add(Dropout(0.20))
# model.add(Dense(32,activation='relu',kernel_regularizer='l2'))
# model.add(Dense(32,activation='relu',kernel_regularizer='l2'))
# model.add(Dense(1,activation='relu'))
# model.add(Dense(16,activation='relu'))
# model.add(Dropout(0.20))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 125, 100)          1818400
#
#  bidirectional_5 (Bidirectio  (None, 256)              234496
#  nal)
#
#  flatten_5 (Flatten)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 64)                16448
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 2,069,409
# Trainable params: 2,069,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import keras
from keras import optimizers
import tensorflow_addons as tfa

# %%
from tensorflow_addons.optimizers import weight_decay_optimizers
model.compile(optimizer=keras.optimizers.RMSprop(lr=0.0005),loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
epochs=50
batch_size=128

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %%
model.fit(X_train,y_train,epochs=epochs,batch_size=batch_size,validation_data=(X_val,y_val),callbacks=[es, mc])
# Out:
# Epoch 1/50
# 115/116 [============================>.] - ETA: 0s - loss: 1.0891 - accuracy: 0.7451
# Epoch 1: val_accuracy improved from -inf to 0.82939, saving model to best_model.h5
# 116/116 [==============================] - 8s 42ms/step - loss: 1.0853 - accuracy: 0.7462 - val_loss: 0.6926 - val_accuracy: 0.8294
# Epoch 2/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.8406
# Epoch 2: val_accuracy improved from 0.82939 to 0.84031, saving model to best_model.h5
# 116/116 [==============================] - 4s 35ms/step - loss: 0.5481 - accuracy: 0.8404 - val_loss: 0.4516 - val_accuracy: 0.8403
# Epoch 3/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.3936 - accuracy: 0.8605
# Epoch 3: val_accuracy improved from 0.84031 to 0.85345, saving model to best_model.h5
# 116/116 [==============================] - 4s 35ms/step - loss: 0.3924 - accuracy: 0.8611 - val_loss: 0.3718 - val_accuracy: 0.8534
# Epoch 4/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.3339 - accuracy: 0.8751
# Epoch 4: val_accuracy did not improve from 0.85345
# 116/116 [==============================] - 3s 23ms/step - loss: 0.3347 - accuracy: 0.8746 - val_loss: 0.3810 - val_accuracy: 0.8508
# Epoch 5/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.3021 - accuracy: 0.8840
# Epoch 5: val_accuracy improved from 0.85345 to 0.86699, saving model to best_model.h5
# 116/116 [==============================] - 4s 35ms/step - loss: 0.3021 - accuracy: 0.8840 - val_loss: 0.3164 - val_accuracy: 0.8670
# Epoch 6/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.2803 - accuracy: 0.8921
# Epoch 6: val_accuracy improved from 0.86699 to 0.87305, saving model to best_model.h5
# 116/116 [==============================] - 5s 39ms/step - loss: 0.2802 - accuracy: 0.8922 - val_loss: 0.3148 - val_accuracy: 0.8731
# Epoch 7/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.2630 - accuracy: 0.8982
# Epoch 7: val_accuracy improved from 0.87305 to 0.87326, saving model to best_model.h5
# 116/116 [==============================] - 4s 36ms/step - loss: 0.2624 - accuracy: 0.8985 - val_loss: 0.3103 - val_accuracy: 0.8733
# Epoch 8/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.2399 - accuracy: 0.9120
# Epoch 8: val_accuracy improved from 0.87326 to 0.88154, saving model to best_model.h5
# 116/116 [==============================] - 4s 35ms/step - loss: 0.2397 - accuracy: 0.9122 - val_loss: 0.3134 - val_accuracy: 0.8815
# Epoch 9/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9220
# Epoch 9: val_accuracy did not improve from 0.88154
# 116/116 [==============================] - 3s 23ms/step - loss: 0.2224 - accuracy: 0.9219 - val_loss: 0.3047 - val_accuracy: 0.8813
# Epoch 10/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.2108 - accuracy: 0.9234
# Epoch 10: val_accuracy improved from 0.88154 to 0.88175, saving model to best_model.h5
# 116/116 [==============================] - 4s 35ms/step - loss: 0.2108 - accuracy: 0.9235 - val_loss: 0.3035 - val_accuracy: 0.8817
# Epoch 11/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.1918 - accuracy: 0.9325
# Epoch 11: val_accuracy did not improve from 0.88175
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1919 - accuracy: 0.9326 - val_loss: 0.3127 - val_accuracy: 0.8803
# Epoch 12/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.1799 - accuracy: 0.9382
# Epoch 12: val_accuracy did not improve from 0.88175
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1794 - accuracy: 0.9384 - val_loss: 0.3288 - val_accuracy: 0.8817
# Epoch 13/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.1621 - accuracy: 0.9458
# Epoch 13: val_accuracy did not improve from 0.88175
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1624 - accuracy: 0.9456 - val_loss: 0.3529 - val_accuracy: 0.8672
# Epoch 14/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9504
# Epoch 14: val_accuracy did not improve from 0.88175
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1496 - accuracy: 0.9503 - val_loss: 0.3374 - val_accuracy: 0.8793
# Epoch 15/50
# 115/116 [============================>.] - ETA: 0s - loss: 0.1372 - accuracy: 0.9557
# Epoch 15: val_accuracy did not improve from 0.88175
# 116/116 [==============================] - 3s 23ms/step - loss: 0.1381 - accuracy: 0.9552 - val_loss: 0.3554 - val_accuracy: 0.8759
# Epoch 15: early stopping

# %%
modelx = keras.models.load_model('best_model.h5')

# %%
y_pred_one_hot_encoded = (modelx.predict(X_test)> 0.5).astype("float")
#y_pred_test = np.array(tf.argmax(y_pred_one_hot_encoded, axis=1))

# %%
print(classification_report(y_test, y_pred_one_hot_encoded,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8798    0.8826    0.8812      2471
#            1     0.8825    0.8796    0.8811      2476
#
#     accuracy                         0.8811      4947
#    macro avg     0.8811    0.8811    0.8811      4947
# weighted avg     0.8811    0.8811    0.8811      4947

# %%
modelx.evaluate(X_test, y_test, batch_size=64)
# Out:
# 78/78 [==============================] - 1s 8ms/step - loss: 0.3124 - accuracy: 0.8811
# [0.3123956322669983, 0.8811401128768921]

# %%
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
dicchar = loaddicchar()

# Hàm chuyển Unicode dựng sẵn về Unicde tổ hợp (phổ biến hơn)
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

def chuan_hoa_dau_cau_tieng_viet(sentence):
    """
        Chuyển câu tiếng việt về chuẩn gõ dấu kiểu cũ.
        :param sentence:
        :return:
        """
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        words[index] = ''.join(cw)
    return ' '.join(words)

def remove_html(txt):
    return re.sub(r'<[^>]*>', '', txt)

# %%
def text_preprocess(document):
    # xóa html code
    document = remove_html(document)
    # chuẩn hóa unicode
    document = convert_unicode(document)
    
    # đưa về lower
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    # tách từ
    document = word_tokenize(document, format="text")
    return document

# %%
# lst_stopword = []
# with open('/content/drive/MyDrive/KhanhMD/Data/vietnamese-stopwords.txt','r') as f:
#     for line in f:
#         for word in line.split():
#            lst_stopword.append(word)  
    
# def remove_stopwords(line):
#     words = []
#     for word in line.strip().split():
#         if word not in lst_stopword:
#             words.append(word)
#     return ' '.join(words)

# %%
document = 'Tụi mình đi 3 đứa , lúc chọn lẩu xog , có nhờ order thêm dùm 2 chai nước với một khay nước_tương , tụi mình nhờ đúng 6 đứa phục_vụ mà nói_đúng_ra tụi nó ừm ờ r kiểu nhường nhau , k có đứa nào lấy hết , phải nói điên tiếc cả người , lúc về kiểu như đuổi khách , làm_ăn như z mất khách hết , một đi KHÔNG_BAO_GIỜ trở_lại'

document = text_preprocess(document)
document = [document]
print(document)
#tok.fit_on_texts(df['text'])
encd = tok.texts_to_sequences(document)
encd
# Out:
# ['tụi mình đi 3 đứa lúc chọn lẩu xog có nhờ order thêm dùm 2 chai nước với một khay nước_tương tụi_mình nhờ đúng 6 đứa phục_vụ mà nói_đúng_ra tụi nó ừm ờ r kiểu nhường nhau k có đứa nào lấy hết phải nói điên tiếc cả người lúc về kiểu như đuổi khách làm_ăn như z mất khách hết một đi không_bao_giờ trở_lại']
# [[428,
#   2,
#   23,
#   95,
#   335,
#   89,
#   274,
#   188,
#   1816,
#   3,
#   845,
#   243,
#   96,
#   1306,
#   42,
#   720,
#   45,
#   30,
#   84,
#   1673,
#   45,
#   368,
#   428,
#   2,
#   845,
#   250,
#   439,
#   335,
#   46,
#   38,
#   13,
#   40,
#   250,
#   35,
#   428,
#   247,
#   6347,
#   2443,
#   597,
#   235,
#   3033,
#   357,
#   14,
#   3,
#   335,
#   80,
#   315,
#   88,
#   51,
#   40,
#   1853,
#   796,
#   52,
#   65,
#   89,
#   86,
#   235,
#   29,
#   1236,
#   56,
#   78,
#   1,
#   29,
#   2086,
#   347,
#   56,
#   88,
#   84,
#   23,
#   4,
#   181,
#   166,
#   630,
#   22]]

# %%
pad= pad_sequences(encd, maxlen=max_rev_len, padding='post')

# %%
predict_x = modelx.predict(pad)
predict_x
# Out:
# array([[0.00297315]], dtype=float32)
